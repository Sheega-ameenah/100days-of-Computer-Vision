# %%
import cv2

# %%
cam= cv2.VideoCapture(0)

# %%
cam.read()
# Out:
# (True,
#  array([[[30, 33, 33],
#          [30, 33, 32],
#          [30, 34, 31],
#          ...,
#          [24, 27, 27],
#          [24, 27, 27],
#          [25, 28, 28]],
#
#         [[30, 33, 33],
#          [30, 33, 33],
#          [30, 33, 33],
#          ...,
#          [23, 26, 26],
#          [23, 26, 26],
#          [24, 27, 27]],
#
#         [[30, 33, 33],
#          [30, 33, 33],
#          [30, 33, 33],
#          ...,
#          [23, 26, 26],
#          [24, 27, 27],
#          [24, 27, 27]],
#
#         ...,
#
#         [[28, 26, 29],
#          [28, 26, 29],
#          [28, 26, 29],
#          ...,
#          [22, 24, 23],
#          [24, 25, 23],
#          [24, 25, 23]],
#
#         [[28, 26, 29],
#          [28, 26, 29],
#          [28, 26, 29],
#          ...,
#          [24, 24, 26],
#          [26, 24, 27],
#          [26, 24, 27]],
#
#         [[28, 26, 29],
#          [28, 26, 29],
#          [27, 25, 28],
#          ...,
#          [25, 25, 25],
# ...

# %%
ret,frame = cam.read()

# %%
import matplotlib.pyplot as plt
if ret:
    plt.imshow(frame)

# %%
plt.imsave('Boddo.jpg',frame)
